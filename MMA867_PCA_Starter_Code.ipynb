# %% [markdown]
# # MMA 867 Team Project - PCA Analysis

# %%
# Import required Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %% [markdown]
# ## Section 1: Data Ingestion

# %%
# Load all project files for the team assignment
df_train_predictors = pd.read_csv('Training_Data_Predictors.csv')
df_train_target = pd.read_csv('Train_Target.csv')

# %%
df_train_predictors
# Out:
#       ID  Page total likes   Type  Category  Post Month  Post Weekday  \
# 0      1            131630  Photo         3           7             2
# 1      2            116435  Photo         3           5             3
# 2      3            109670  Photo         1           4             6
# 3      4            138895  Video         1          12             4
# 4      5            126345  Photo         1           6             2
# ..   ...               ...    ...       ...         ...           ...
# 395  396            119198  Photo         3           5             6
# 396  397            134879  Photo         1           9             1
# 397  398            138458  Photo         3          12             5
# 398  399            129600  Photo         3           7             2
# 399  400            138895  Photo         3          12             2
#
#      Post Hour  Paid  Lifetime Post Total Reach  \
# 0           23   0.0                       2822
# ...

# %%
df_train_target.head()
# Out:
#    ID  Total_Interactions
# 0   1                 135
# 1   2                 429
# 2   3                  87
# 3   4                 174
# 4   5                 218

# %%
df = pd.merge(df_train_predictors, df_train_target, on="ID")

df.head()
# Out:
#    ID  Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0   1            131630  Photo         3           7             2         23
# 1   2            116435  Photo         3           5             3          7
# 2   3            109670  Photo         1           4             6         13
# 3   4            138895  Video         1          12             4         11
# 4   5            126345  Photo         1           6             2          9
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2822                             5058
# 1   0.0                      18552                            25542
# 2   0.0                       6172                            10417
# 3   1.0                      36208                            61262
# 4   1.0                       5854                            11854
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.describe()
# Out:
#                ID  Page total likes    Category  Post Month  Post Weekday  \
# count  400.000000        400.000000  400.000000  400.000000    400.000000
# mean   200.500000     123871.910000    1.882500    7.165000      4.192500
# std    115.614301      16056.476886    0.851767    3.287064      2.027491
# min      1.000000      81370.000000    1.000000    1.000000      1.000000
# 25%    100.750000     115368.000000    1.000000    4.000000      2.000000
# 50%    200.500000     130791.000000    2.000000    7.000000      4.000000
# 75%    300.250000     136642.000000    3.000000   10.000000      6.000000
# max    400.000000     139441.000000    3.000000   12.000000      7.000000
#
#         Post Hour        Paid  Lifetime Post Total Reach  \
# count  400.000000  399.000000                 400.000000
# mean     7.807500    0.280702               13859.785000
# std      4.345417    0.449906               22403.733379
# min      1.000000    0.000000                 238.000000
# ...

# %% [markdown]
# ## Section 2: EDA & Data Cleaning
# *(To be completed by teammate responsible for identifying unusual employees)*

# %% [markdown]
# <h5 style="color: blue;">EDA & Data Cleaning Findings & Conclusion</h5>
#
# Write your conclusion in point form here:
# 1. ....
# 2. ....
# 3. ....

# %% [markdown]
# ## Section 3: PCA & Modelling
# *(To be completed by teammate responsible for identifying unusual employees)*

# %% [markdown]
# <h5 style="color: blue;">PCA & Modelling Findings & Conclusion</h5>
#
# Write your conclusion in point form here:
# 1. ....
# 2. ....
# 3. ....

# %% [markdown]
# ## Section 4: PCA Loadings
# *(To be completed by teammate responsible for identifying question-to-theme mapping)*

# %% [markdown]
# ## Section 5: Modelling Evaluation
# *(To be completed by teammate responsible for identifying unusual employees)*

# %% [markdown]
# <h5 style="color: blue;">Modelling Evaluation Findings & Conclusion</h5>
#
# Write your conclusion in point form here:
# 1. ....
# 2. ....
# 3. ....
